# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('./train - train.csv')
print("n_features: ", train.shape[1])
print("n_columns: ", train.shape[0])
train.head()
# Out:
# n_features:  21
# n_columns:  2000
#    battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0            842     0          2.2         0   1.0     0.0         7.0
# 1           1021     1          0.5         1   0.0     1.0        53.0
# 2            563     1          0.5         1   2.0     1.0        41.0
# 3            615     1          2.5         0   0.0     0.0        10.0
# 4           1821     1          1.2         0  13.0     1.0        44.0
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 0    0.6      188.0      2.0  ...       20.0     756.0  2549.0   9.0   7.0
# 1    0.7      136.0      3.0  ...      905.0    1988.0  2631.0  17.0   3.0
# 2    0.9      145.0      5.0  ...     1263.0    1716.0  2603.0  11.0   2.0
# 3    0.8      131.0      6.0  ...     1216.0    1786.0  2769.0  16.0   8.0
# 4    0.6      141.0      2.0  ...     1208.0    1212.0  1411.0   8.0   2.0
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             1995 non-null   float64
#  5   four_g         1995 non-null   float64
#  6   int_memory     1995 non-null   float64
#  7   m_dep          1995 non-null   float64
#  8   mobile_wt      1996 non-null   float64
#  9   n_cores        1996 non-null   float64
#  10  pc             1995 non-null   float64
#  11  px_height      1996 non-null   float64
#  12  px_width       1998 non-null   float64
#  13  ram            1998 non-null   float64
#  14  sc_h           1999 non-null   float64
#  15  sc_w           1999 non-null   float64
#  16  talk_time      2000 non-null   int64
# ...

# %% [markdown]
# ### Function to Plot uniques Values in All Variables in DataFrame

# %%
def plot_unique_values(dataframe):
    # Iterate over each feature
    for column in dataframe.columns:
        unique_values = dataframe[column].nunique()
        missing_values = dataframe[column].isnull().sum()  # Count missing values
        
        # If the feature has more than ten unique values, plot the ten most frequent values
        if unique_values > 10:
            most_frequent_values = dataframe[column].value_counts().nlargest(10)
            plt.figure(figsize=(8, 4))
            sns.countplot(x=column, data=dataframe, order=most_frequent_values.index, hue=column, palette='viridis', legend=False)
            plt.title(f"Top 10 Most Frequent Values - {column}")
            plt.xlabel(column)
            plt.ylabel("Count")
            plt.xticks(rotation=45)
            plt.show()
            print(f"Only the top 10 most frequent values are plotted out of {unique_values} unique values for {column}.")
        else:
            plt.figure(figsize=(8, 4))
            sns.countplot(x=column, data=dataframe, order=dataframe[column].value_counts().index, palette='viridis', hue=column, legend=False)
            plt.title(f"Unique Values - {column}")
            plt.xlabel(column)
            plt.ylabel("Count")
            plt.xticks(rotation=45)
            plt.show()
            print(f"All unique values ({unique_values}) are plotted for {column}.")
        
        print(f"Missing values in {column}: {missing_values}({missing_values / len(dataframe[column]):.3f}%)\n")

# %%
plot_unique_values(train)
# Out:
# Only the top 10 most frequent values are plotted out of 1094 unique values for battery_power.
# Missing values in battery_power: 0(0.000%)
# All unique values (2) are plotted for blue.
# Missing values in blue: 0(0.000%)
# Only the top 10 most frequent values are plotted out of 26 unique values for clock_speed.
# Missing values in clock_speed: 0(0.000%)
# All unique values (2) are plotted for dual_sim.
# Missing values in dual_sim: 0(0.000%)
# Only the top 10 most frequent values are plotted out of 20 unique values for fc.
# Missing values in fc: 5(0.003%)
# All unique values (2) are plotted for four_g.
# Missing values in four_g: 5(0.003%)
# Only the top 10 most frequent values are plotted out of 63 unique values for int_memory.
# Missing values in int_memory: 5(0.003%)
# All unique values (10) are plotted for m_dep.
# Missing values in m_dep: 5(0.003%)
# Only the top 10 most frequent values are plotted out of 121 unique values for mobile_wt.
# ...

# %%
# Filter rows with missing values
train[train.isna().sum(axis=1) > 0]
# Out:
#      battery_power  blue  clock_speed  dual_sim   fc  four_g  int_memory  \
# 157           1224     0          0.5         0  NaN     NaN         NaN
# 158           1356     0          2.8         0  NaN     NaN         NaN
# 217           1336     0          0.9         0  5.0     1.0        17.0
# 261            728     0          2.7         1  NaN     NaN         NaN
# 276           1662     0          0.5         0  NaN     NaN         NaN
# 292           1995     1          1.9         0  6.0     0.0         9.0
# 293           1517     0          0.5         0  6.0     1.0        48.0
# 341            811     1          2.4         1  5.0     1.0         2.0
# 371           1011     0          1.1         0  NaN     NaN         NaN
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 157    NaN        NaN      NaN  ...      747.0     826.0   506.0  10.0   0.0
# 158    NaN        NaN      NaN  ...     1612.0    1983.0  3702.0  17.0   0.0
# ...

# %% [markdown]
# * It looks like there are only 9 devices with missing values so there is no problem deleting them

# %%
# Remove rows with missing values
train = train.dropna()

print("DataFrame after removing rows with missing values:", train.shape)
# Out:
# DataFrame after removing rows with missing values: (1991, 21)

# %%
# Check data types of columns
categorical_columns = train.select_dtypes(include=['object', 'category']).columns

print("Categorical variables:")
print(categorical_columns)
# Out:
# Categorical variables:
# Index([], dtype='object')

# %% [markdown]
# - Nice! All The Data we have is Numeric!

# %% [markdown]
# ## Let's Discover Some Weirdness in the Data.

# %% [markdown]
# ### Unique Combinations of px_height and px_width

# %%
# Plot unique combinations of px_height and px_width
plt.figure(figsize=(8, 6))
sns.scatterplot(x='px_height', y='px_width', data=train, color='skyblue')
# Out:
# <Axes: xlabel='px_height', ylabel='px_width'>

# %% [markdown]
# ### Unique Combinations of sc_w and sc_h

# %%
# Plot unique combinations of sc_w and sc_h
plt.figure(figsize=(8, 6))
sns.scatterplot(x='sc_h', y='sc_w', data=train, color='skyblue')
# Out:
# <Axes: xlabel='sc_h', ylabel='sc_w'>

# %% [markdown]
# ### the Relationship between battery_power and talk_time

# %%
# Plot scatter plot to show the relationship between battery_power and talk_time
plt.figure(figsize=(8, 6))
sns.scatterplot(x='battery_power', y='talk_time', data=train, color='skyblue')
# Out:
# <Axes: xlabel='battery_power', ylabel='talk_time'>

# %% [markdown]
# ## Feature Engineering
# ### Create a New Feature, screen_area

# %%
# Calculate screen area
train['screen_area'] = train['sc_w'] * train['sc_h']

# %% [markdown]
# ### The Relationship between mobile_wt and screen_area

# %%
# Plot scatter plot to show the relationship between mobile_wt and screen_area
plt.figure(figsize=(8, 6))
sns.scatterplot(x='mobile_wt', y='screen_area', data=train, color='skyblue')
# Out:
# <Axes: xlabel='mobile_wt', ylabel='screen_area'>

# %% [markdown]
# ### The Relationship between int_memory and ram

# %%
# Plot scatter plot to show the relationship between int_memory and ram
plt.figure(figsize=(8, 6))
sns.scatterplot(x='int_memory', y='ram', data=train, color='skyblue')
# Out:
# <Axes: xlabel='int_memory', ylabel='ram'>

# %% [markdown]
# ## Feature Engineering
# ### Create a New Feature, volume

# %%
# Calculate screen area
train['volume'] = train['sc_w'] * train['sc_h'] * train['m_dep']

# %% [markdown]
# ### The Relationship between mobile_wt and Volume

# %%
# Plot scatter plot to show the relationship between mobile_wt and Volume
plt.figure(figsize=(8, 6))
plt.scatter(train['mobile_wt'], train['volume'], color='skyblue', alpha=0.7)
plt.xlabel('Mobile Weight (g)')
plt.ylabel('Volume (px)')
plt.title('Relationship between Mobile Weight and Volume')
plt.grid(True)
plt.show()

# %% [markdown]
# `Very weird! There is no relationship that is supposed to be between the above features! The data look like randomly generated!`

# %% [markdown]
# ### The Relationship between RAM and price_range

# %%
# Plot box plot to show the relationship between RAM and price_range
plt.figure(figsize=(8, 6))
sns.boxplot(x='price_range', y='ram', data=train, palette='viridis')
plt.xlabel('Price Range')
plt.ylabel('RAM')
plt.title('Relationship between RAM and Price Range')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16152\2095316492.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='price_range', y='ram', data=train, palette='viridis')

# %% [markdown]
# `Aha! Some Patterns have been Discovered!`

# %% [markdown]
# ### The Relationship between battery_power and price_range

# %%
# Plot box plot to show the relationship between battery_power and price_range
plt.figure(figsize=(8, 6))
sns.boxplot(x='price_range', y='battery_power', data=train, palette='viridis')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16152\1765076080.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='price_range', y='battery_power', data=train, palette='viridis')
# <Axes: xlabel='price_range', ylabel='battery_power'>

# %% [markdown]
# `There is a slight relationship between battery size and device price`

# %%
from sklearn.feature_selection import mutual_info_classif

# For classification tasks
mutual_info = mutual_info_classif(train.drop('price_range', axis=1), train['price_range'])

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.bar(train.drop('price_range', axis=1).columns, mutual_info, color='skyblue')
plt.xlabel('Features')
plt.ylabel('Mutual Information')
plt.title('Mutual Information Scores for Features')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# `only RAM feature show a Strong Relation with price_range`

# %%
correlation_matrix = train.corr()

# Plot correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Function to remove some Features that show some Correlation with others Features so there is no need to deal with both, and to Create Some New Features

# %%
def func(df):
    # Remove 'sc_h' and 'sc_w' and 'pc'
    df.drop(['sc_h', 'sc_w', 'pc'], axis=1, inplace=True)

    # Replace 'px_width' and 'px_height' with 'resolution' by multiplying them
    df['resolution'] = df['px_width'] * df['px_height']
    df.drop(['px_width', 'px_height'], axis=1, inplace=True)

    # Replace 'three_g' and 'four_g' with 'network_fast'
    df['network_fast'] = df['three_g'] + 2 * df['four_g']
    df.drop(['three_g', 'four_g'], axis=1, inplace=True)
    return df

# %%
train = func(train)

# %%
correlation_matrix = train.corr()

# Plot correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## The Main Function to fit the Data and know the Evaluation Results

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_classification_model(model, X_train, y_train, X_test, y_test):
    """
    Evaluate a classification model using commonly used metrics.
    
    Parameters:
        model: The classification model to be evaluated.
        X_train: The feature matrix of the training dataset.
        y_train: The target labels of the training dataset.
        X_test: The feature matrix of the testing dataset.
        y_test: The target labels of the testing dataset.
    
    Returns:
        metrics_results: A list of metric results including accuracy, precision, recall, F1-score,
                         ROC AUC score, and confusion matrix.
    """
    # Fit the model on the training data
    model.fit(X_train, y_train)
    
    # Predict on the testing data
    y_pred = model.predict(X_test)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    
    # Create a dictionary to store the metric results
    metrics_results = {
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    }
    
    return metrics_results

# %% [markdown]
# ## Import many Libraries We will need

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.svm import SVC

# %%
X = train.drop('price_range', axis=1)
y = train['price_range']

# %%
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim    fc  int_memory  m_dep  \
# 0            842     0          2.2         0   1.0         7.0    0.6
# 1           1021     1          0.5         1   0.0        53.0    0.7
# 2            563     1          0.5         1   2.0        41.0    0.9
# 3            615     1          2.5         0   0.0        10.0    0.8
# 4           1821     1          1.2         0  13.0        44.0    0.6
#
#    mobile_wt  n_cores     ram  talk_time  touch_screen  wifi  screen_area  \
# 0      188.0      2.0  2549.0         19             0     1         63.0
# 1      136.0      3.0  2631.0          7             1     0         51.0
# 2      145.0      5.0  2603.0          9             1     0         22.0
# 3      131.0      6.0  2769.0         11             0     0        128.0
# 4      141.0      2.0  1411.0         15             1     0         16.0
#
#    volume  resolution  network_fast
# 0    37.8     15120.0           0.0
# ...

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %% [markdown]
# ## Let's Try Some Methods

# %% [markdown]
# ## SVM

# %%
evaluate_classification_model(model=SVC(), X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test)
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'Accuracy': 0.3233082706766917,
#  'Precision': 0.23331861462912906,
#  'Recall': 0.3233082706766917,
#  'F1 Score': 0.2644829797507233}

# %% [markdown]
# ## Decision Tree

# %%
evaluate_classification_model(model=DecisionTreeClassifier(), X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test)
# Out:
# {'Accuracy': 0.8571428571428571,
#  'Precision': 0.8588126050570527,
#  'Recall': 0.8571428571428571,
#  'F1 Score': 0.8578383756317355}

# %% [markdown]
# ## Random Forest

# %%
evaluate_classification_model(model=RandomForestClassifier(), X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test)
# Out:
# {'Accuracy': 0.8822055137844611,
#  'Precision': 0.880638693215951,
#  'Recall': 0.8822055137844611,
#  'F1 Score': 0.8807766309654913}

# %% [markdown]
# ## XGBoosting

# %%
evaluate_classification_model(model=XGBClassifier(), X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test)
# Out:
# {'Accuracy': 0.9022556390977443,
#  'Precision': 0.9018573212757333,
#  'Recall': 0.9022556390977443,
#  'F1 Score': 0.9018323946702643}

# %% [markdown]
# ## What About PCA?

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize PCA
pca = PCA(n_components=0.95)  # Specify the variance to be preserved (e.g., 95%)
# Fit PCA on the training data
X_train_pca = pca.fit_transform(X_train_scaled)
# Transform the testing data
X_test_pca = pca.transform(X_test_scaled)

# Print the number of components retained
print("Number of components retained:", pca.n_components_)
# Out:
# Number of components retained: 16

# %%
evaluate_classification_model(model=XGBClassifier(), X_train=X_train_pca, X_test=X_test_pca, y_train=y_train, y_test=y_test)
# Out:
# {'Accuracy': 0.7243107769423559,
#  'Precision': 0.7279208579518178,
#  'Recall': 0.7243107769423559,
#  'F1 Score': 0.7254345428654442}

# %% [markdown]
# ## Let's try with some Selected Features

# %%
features = ['battery_power', 'ram', 'resolution', 'network_fast', 'screen_area', 'fc']
X.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'int_memory',
#        'm_dep', 'mobile_wt', 'n_cores', 'ram', 'talk_time', 'touch_screen',
#        'wifi', 'screen_area', 'volume', 'resolution', 'network_fast'],
#       dtype='object')

# %%
evaluate_classification_model(model=XGBClassifier(), X_train=X_train[features], X_test=X_test[features], y_train=y_train, y_test=y_test)
# Out:
# {'Accuracy': 0.9122807017543859,
#  'Precision': 0.9118961298640617,
#  'Recall': 0.9122807017543859,
#  'F1 Score': 0.9120314939557094}

# %% [markdown]
# `Better! An understandable result given the nature of the features and their relationship between them, as shown by Charts Above`

# %% [markdown]
# ## Let's Train a new Model with A whole Data

# %%
model = XGBClassifier()
model.fit(X[features], y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
import pickle

file_path = 'final_model.pkl'

# Save the model to disk
with open(file_path, 'wb') as f:
    pickle.dump(model, f)

print("XGBoost model saved successfully at:", file_path)
# Out:
# XGBoost model saved successfully at: final_model.pkl

# %%
X[features]
# Out:
#       battery_power     ram  resolution  network_fast  screen_area    fc
# 0               842  2549.0     15120.0           0.0         63.0   1.0
# 1              1021  2631.0   1799140.0           3.0         51.0   0.0
# 2               563  2603.0   2167308.0           3.0         22.0   2.0
# 3               615  2769.0   2171776.0           1.0        128.0   0.0
# 4              1821  1411.0   1464096.0           3.0         16.0  13.0
# ...             ...     ...         ...           ...          ...   ...
# 1995            794   668.0   2309580.0           3.0         52.0   0.0
# 1996           1965  2032.0   1797975.0           1.0        110.0   0.0
# 1997           1911  3057.0   1416576.0           3.0          9.0   1.0
# 1998           1512   869.0    225120.0           3.0        180.0   4.0
# 1999            510  3919.0    364182.0           3.0         76.0   5.0
#
# [1991 rows x 6 columns]
